# %%
import pandas as pd
from datetime import datetime as dt, timedelta
from dateutil import parser
import requests
from constants.definitions import API_KEY, ACCOUNT_ID, OANDA_URL
from infrastructure.exceptions import NullCandles, RequestError, InvalidFunctionArguments

# %%
# initialise a session and set headers
session = requests.Session()
session.headers.update({
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json",
})

url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/instruments"

# %%
# get a list of all tradeable instruments for the account
response = session.get(url)
response.raise_for_status()
instruments = response.json()["instruments"] if "instruments" in response.json() else []

# %%
instruments_names = [i["name"] for i in instruments]
instruments_names
# Out:
# ['USD_CNH',
#  'NZD_CAD',
#  'EUR_CHF',
#  'SGD_CHF',
#  'XAU_AUD',
#  'WHEAT_USD',
#  'EUR_CZK',
#  'XAG_USD',
#  'NZD_JPY',
#  'CHF_HKD',
#  'EUR_GBP',
#  'US30_USD',
#  'EUR_NOK',
#  'JP225Y_JPY',
#  'USD_CZK',
#  'CN50_USD',
#  'GBP_NZD',
#  'XAU_USD',
#  'EUR_SEK',
#  'USD_SGD',
#  'GBP_PLN',
#  'CH20_CHF',
#  'CAD_HKD',
#  'XAG_CHF',
#  'USD_CHF',
#  'XAG_HKD',
#  'AUD_HKD',
#  'ESPIX_EUR',
#  'NZD_CHF',
#  'AUD_CHF',
#  'GBP_CHF',
#  'USD_THB',
#  'XAU_JPY',
#  'XAU_HKD',
#  'GBP_CAD',
#  'EUR_HKD',
#  'CHF_JPY',
#  'GBP_HKD',
#  'EUR_NZD',
#  'XAG_AUD',
#  'WTICO_USD',
#  'XAG_NZD',
#  'AUD_SGD',
#  'EUR_JPY',
#  'EUR_TRY',
#  'USD_JPY',
#  'SGD_JPY',
#  'GBP_ZAR',
#  'XAG_JPY',
#  'ZAR_JPY',
#  'NZD_SGD',
#  'GBP_JPY',
#  'USD_TRY',
#  'TRY_JPY',
#  'XAU_NZD',
#  'HK33_HKD',
#  'XAG_GBP',
#  'EUR_SGD',
#  'EUR_AUD',
#  'XAU_SGD',
#  'USD_CAD',
#  'SPX500_USD',
#  'USB10Y_USD',
#  'EU50_EUR',
#  'CAD_CHF',
#  'USD_NOK',
#  'USB02Y_USD',
#  'XCU_USD',
#  'AUD_USD',
#  'XAG_EUR',
#  'AUD_JPY',
#  'EUR_ZAR',
#  'CHF_ZAR',
#  'USD_HKD',
#  'CHINAH_HKD',
#  'USD_PLN',
#  'GBP_AUD',
#  'NAS100_USD',
#  'XAU_GBP',
#  'XAU_XAG',
#  'AU200_AUD',
#  'USD_DKK',
#  'XPT_USD',
#  'XAU_EUR',
#  'SOYBN_USD',
#  'EUR_USD',
#  'SG30_SGD',
#  'USD_ZAR',
#  'CAD_JPY',
#  'NL25_EUR',
#  'CORN_USD',
#  'NZD_USD',
#  'BCO_USD',
#  'NZD_HKD',
#  'AUD_NZD',
#  'XAG_SGD',
#  'USB30Y_USD',
#  'FR40_EUR',
#  'JP225_USD',
#  'CAD_SGD',
#  'XAU_CHF',
#  'GBP_USD',
#  'USD_MXN',
#  'AUD_CAD',
#  'USD_HUF',
#  'EUR_CAD',
#  'UK10YB_GBP',
#  'NATGAS_USD',
#  'XAU_CAD',
#  'EUR_DKK',
#  'XAG_CAD',
#  'USB05Y_USD',
#  'DE30_EUR',
#  'USD_SEK',
#  'GBP_SGD',
#  'XPD_USD',
#  'DE10YB_EUR',
#  'EUR_PLN',
#  'SUGAR_USD',
#  'HKD_JPY',
#  'UK100_GBP',
#  'US2000_USD',
#  'EUR_HUF']

# %%
instruments_df = pd.DataFrame(instruments)

# %%
instruments_df.to_csv("../data/instruments/tradeable_instruments.csv")

# %%
instruments_names = instruments_df["name"].tolist()

# %%
CANDLE_COUNT = 4000
INCREMENTS = {
    "M5": 5 * CANDLE_COUNT,
    "M1": CANDLE_COUNT,
    "M30": 30 * CANDLE_COUNT,
    "M15": 15 *  CANDLE_COUNT,
    "H1": 60 * CANDLE_COUNT,
    "H4": 60 * 4 * CANDLE_COUNT,
    "D": 60 * 24 * CANDLE_COUNT,
}
granularity_list = list(INCREMENTS.keys())

# %%
def calculate_candles_between(from_date: str, to_date: str, granularity: str) -> int:
    """
    Calculate the number of candles between two dates based on the specified granularity.

    :param from_date: Start date in 'YYYY-MM-DDTHH:MM:SSZ' or 'YYYY-MM-DD' format.
    :param to_date: End date in 'YYYY-MM-DDTHH:MM:SSZ' or 'YYYY-MM-DD' format.
    :param granularity: Granularity (timeframe) as a string, e.g., 'M1', 'M5', 'M30', 'H1', 'H2', 'H4', 'D', 'W'.
    :return: Number of candles between the two dates.
    """

    # Convert string dates to datetime objects
    date_format = "%Y-%m-%dT%H:%M:%SZ" if "T" in from_date else "%Y-%m-%d"
    dt1 = dt.strptime(from_date, date_format)
    dt2 = dt.strptime(to_date, date_format)

    if dt1 >= dt2:
        raise ValueError("date1 must be earlier than date2")

    # Match the granularity and calculate the time delta in minutes
    match granularity:
        case "M1":
            delta_minutes = 1
        case "M5":
            delta_minutes = 5
        case "M30":
            delta_minutes = 30
        case "H1":
            delta_minutes = 60
        case "H2":
            delta_minutes = 120
        case "H4":
            delta_minutes = 240
        case "D":
            delta_minutes = 1440  # 24 hours
        case "W":
            delta_minutes = 10080  # 7 days
        case _:
            raise ValueError(f"Unsupported granularity: {granularity}")

    # Calculate the time difference in minutes
    total_minutes = int((dt2 - dt1).total_seconds() / 60)

    # Calculate the number of candles
    candles_count = total_minutes // delta_minutes

    return candles_count

# Example usage
date1 = "2020-01-01T00:00:00Z"
date2 = "2020-01-02T00:00:00Z"
granularity = "M30"

candles = calculate_candles_between(date1, date2, granularity)
print(f"Number of {granularity} candles between {date1} and {date2}: {candles}")
# Out:
# Number of M30 candles between 2020-01-01T00:00:00Z and 2020-01-02T00:00:00Z: 48

# %%
def fetch_candles(pair_name: str, start: str | dt, end: str | dt | None = None, granularity: str = 'H1', count: int = 10, price: str = 'MBA', use_count: bool = False) -> list[dict]:
    """
    Fetches candles for a given pair name. Note that this function assumes that 'requests' library is installed and that
    tradeable instruments are available in its scope
    :param pair_name: pair to request, e.g. 'EUR_USD'
    :param start: date to start fetching candles for, e.g. from '2020-01-01'
    :param end: date to end fetching candles for, e.g. from '2020-01-01' 
    :param granularity: e.g. 'M1', 'M5', 'H1', 'H4'
    :param count: Number of candles to fetch from the date specified in 'start'
    :param price: string representation of price, e.g. 'MBA' or 'B' for bid
    :param use_count: whether to use count or end date in 'end'
    :return returns a dict with candles data as per the specification in the API documentation.
    """
    
    # --------------------- parameter checking ---------------------------------------------------------------------
    if pair_name not in instruments_names:  # NOTE: instruments_names is a list, and it is assumed to be available in the scope
        raise InvalidFunctionArguments(function_name="fetch_candles", arguments=pair_name, message="Pair name must be in 'tradeable_instruments' list")
    if granularity not in INCREMENTS:
        raise InvalidFunctionArguments(function_name="fetch_candles", arguments=granularity, message=f"Granularity must be one of {list(INCREMENTS.keys())}")
    try:
        date_format = "%Y-%m-%dT%H:%M:%SZ"
        
        # if type(start) != str:
        #     print("The error occurs here")
        #     start = dt.strptime(start, date_format)
        #     print("The error occurs here..")
        # else:
        #     start = dt.strftime(parser.parse(start), date_format)
        # if type(end) != str:
        #     end = dt.strptime(end, date_format)
        # else:
        #     end = dt.strftime(parser.parse(end), date_format)

        start = dt.strftime(parser.parse(start), date_format)
        end = dt.strftime(parser.parse(end), date_format) if end is not None else None

    except TypeError:
        raise InvalidFunctionArguments(function_name="fetch_candles", arguments=[start, end], message="Start date must be in 'YYYY-MM-DD' or 'yyyy-mm-ddTh:m:s' format")
    
    if price not in ["MBA", "B", "A", "M"]:
        raise InvalidFunctionArguments(function_name="fetch_candles", arguments=price, message="Price must be one of ['MBA', 'B', 'A', 'M']")
    
    if count not in range(1, CANDLE_COUNT + 1):
        raise InvalidFunctionArguments(function_name="fetch_candles", arguments=count, message="Count must be in range(1, 5000)")
    
    # --------------------- end of parameter checking ----------------------------------------------------------------------
    # if we reach here, all should be good with the provided parameters, proceed with the function operation
    
    request_url = f"{OANDA_URL}/instruments/{pair_name}/candles"
    params = { 'granularity': granularity, 'price': price, 'from': start}
    if use_count and end is None:
        params["count"] = count
    else:
        params["to"] = end
    res = session.get(request_url, params=params)
    # sometimes the data can return with success but will not have 'candles' data in it. We will check for this
    if not res.ok:
        raise RequestError(request_obj=res, message=res.text)
    elif not 'candles' in res.json():
        raise NullCandles(res)
    
    print(params)
    return res.json()['candles']

# %%
temp_df = pd.DataFrame(fetch_candles(
    pair_name='GBP_JPY',
    start="2024-08-01T00:00:00Z",
    end="2024-08-02T00:00:00Z",
    granularity='M30',
    price='MBA',
    use_count=False
))
# Out:
# {'granularity': 'M30', 'price': 'MBA', 'from': '2024-08-01T00:00:00Z', 'to': '2024-08-02T00:00:00Z'}

# %%
temp_df.shape[0]
# Out:
# 48

# %%
temp_df
# Out:
#    complete  volume                            time  \
# 0      True   28399  2024-07-31T21:00:00.000000000Z
# 1      True   49253  2024-08-01T01:00:00.000000000Z
# 2      True   72019  2024-08-01T05:00:00.000000000Z
# 3      True   62336  2024-08-01T09:00:00.000000000Z
# 4      True   80031  2024-08-01T13:00:00.000000000Z
# 5      True   40788  2024-08-01T17:00:00.000000000Z
# 6      True   38622  2024-08-01T21:00:00.000000000Z
#
#                                                  bid  \
# 0  {'o': '192.680', 'h': '193.235', 'l': '191.958...
# 1  {'o': '192.064', 'h': '192.499', 'l': '190.953...
# 2  {'o': '192.335', 'h': '192.730', 'l': '190.971...
# 3  {'o': '191.293', 'h': '193.245', 'l': '190.998...
# 4  {'o': '193.246', 'h': '193.246', 'l': '190.986...
# 5  {'o': '191.165', 'h': '191.222', 'l': '190.154...
# 6  {'o': '190.072', 'h': '190.296', 'l': '189.513...
#
#                                                  mid  \
# 0  {'o': '192.786', 'h': '193.255', 'l': '191.980...
# 1  {'o': '192.083', 'h': '192.517', 'l': '190.972...
# 2  {'o': '192.354', 'h': '192.750', 'l': '190.991...
# 3  {'o': '191.312', 'h': '193.260', 'l': '191.012...
# 4  {'o': '193.260', 'h': '193.260', 'l': '191.003...
# 5  {'o': '191.181', 'h': '191.240', 'l': '190.178...
# 6  {'o': '190.269', 'h': '190.390', 'l': '189.526...
#
#                                                  ask
# 0  {'o': '192.892', 'h': '193.275', 'l': '192.003...
# 1  {'o': '192.102', 'h': '192.535', 'l': '190.989...
# 2  {'o': '192.373', 'h': '192.770', 'l': '191.010...
# 3  {'o': '191.331', 'h': '193.278', 'l': '191.024...
# 4  {'o': '193.274', 'h': '193.275', 'l': '191.020...
# 5  {'o': '191.197', 'h': '191.257', 'l': '190.201...
# 6  {'o': '190.466', 'h': '190.615', 'l': '189.536...

# %%
dt.strftime(parser.parse("2022-01-01"), "%Y-%m-%dT%H:%M:%SZ")
# Out:
# '2022-01-01T00:00:00Z'

# %%
t = "2020-01-01"

# %%
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
def collect_large_candle_data(pair: str, granularity: str, date_from: str, date_to: str, price: str = 'MBA') -> list[dict]:
    """
    Collects large candle data for a given pair and granularity.
    :param pair: pair to request, e.g. 'EUR_USD'
    :param granularity: granularity of candles to fetch
    :param date_from: date from which to start fetching candles for, e.g. from '2020-01-01'
    :param date_to: date to end fetching candles for, e.g. from '2020-01-01'
    :param price: price representation of price, e.g. 'MBA' or 'B' for bid
    :return: list of candles data as per the specification in the API documentation.
    """
    
    # --------------- checking parameters --------------------
    start_date: dt
    end_date: dt
    if pair not in instruments_names:  # NOTE: instruments_names is a list, and it is assumed to be available in the scope
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=pair, message="Pair must be in 'tradeable_instruments' list")
    if granularity not in INCREMENTS:
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=granularity, message=f"Granularity must be one of {list(INCREMENTS.keys())}")
    try:
        start_date = parser.parse(date_from)
        end_date = parser.parse(date_to)
    except TypeError:
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=[date_from, date_to], message="dates must be in 'YYYY-MM-DD' or 'yyyy-mm-ddTh:m:s' format")
    if price not in ["MBA", "B", "A", "M"]:
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=price, message="Price must be one of ['MBA', 'B', 'A', 'M']")
    
    
    candles: list = []
    # TODO: the data collected maybe very large and my consume the memory, update the function to workaround this
    date_format = "%Y-%m-%dT%H:%M:%SZ"
    time_step = INCREMENTS[granularity]
    to_date = start_date + timedelta(seconds=time_step)
    
    
    
    while to_date < end_date:
        print(f"start_date: {start_date}")
        print(f"to_date: {to_date}")
        try:
            fetched_candles = fetch_candles(
                pair_name=pair,
                start=dt.strftime(start_date, date_format),
                granularity=granularity,
                end=dt.strftime(to_date, date_format),
                price=price,
                use_count=False
            )
            
            candles.extend(fetched_candles) 
            start_date =  start_date + timedelta(minutes=time_step)
            to_date += timedelta(minutes=time_step)
            to_date = min(to_date, end_date)
            print("------------------------------------------")
            print(f"start_date: {start_date}")
            print(f"to_date: {to_date}")
        except InvalidFunctionArguments as e:
            print(f"Invalid arguments: {e}")
        except RequestError as e:
            print(f"Request failed: {e}")
        except NullCandles as e:
            print(f"No candle data returned: {e}")
            
            
    return candles

# %%
def collect_large_candle_data(pair: str, granularity: str, date_from: str, date_to: str, price: str = 'MBA') -> list[dict]:
    """
    Collects large candle data for a given pair and granularity.
    :param pair: pair to request, e.g. 'EUR_USD'
    :param granularity: granularity of candles to fetch
    :param date_from: date from which to start fetching candles for, e.g. from '2020-01-01'
    :param date_to: date to end fetching candles for, e.g. from '2020-01-01'
    :param price: price representation of price, e.g. 'MBA' or 'B' for bid
    :return: list of candles data as per the specification in the API documentation.
    """

    # --------------- checking parameters --------------------
    from_date: dt
    to_date: dt
    if pair not in instruments_names:  # NOTE: instruments_names is a list, and it is assumed to be available in the scope
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=pair, message="Pair must be in 'tradeable_instruments' list")
    if granularity not in INCREMENTS:
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=granularity, message=f"Granularity must be one of {list(INCREMENTS.keys())}")
    try:
        from_date = parser.parse(date_from)
        to_date = parser.parse(date_to)
    except TypeError:
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=[date_from, date_to], message="dates must be in 'YYYY-MM-DD' or 'yyyy-mm-ddTh:m:s' format")
    if price not in ["MBA", "B", "A", "M"]:
        raise InvalidFunctionArguments(function_name="collect_large_candle_data", arguments=price, message="Price must be one of ['MBA', 'B', 'A', 'M']")
    
    # ------------- subroutines ------------------------------------
    def get_candles(p_count: int, from_date: dt) -> list:
        try:
            return fetch_candles(
                pair_name=pair,
                start=dt.strftime(from_date, date_format),
                granularity=granularity,
                price=price,
                use_count=True,
                count=p_count
            )
        except InvalidFunctionArguments as e:
            print(f"Invalid arguments: {e}")
        except RequestError as e:
            print(f"Request failed: {e}")
        except NullCandles as e:
            print(f"No candle data returned: {e}")
            
    # ------------ end subroutines --------------------------------


    candles: list = []
    date_format = "%Y-%m-%dT%H:%M:%SZ"
    
    count = calculate_candles_between(
        from_date=dt.strftime(from_date, date_format), 
        to_date=dt.strftime(to_date, date_format),
        granularity=granularity,
    ) + 1
    
    if count <= CANDLE_COUNT: 
        candles.extend(get_candles(p_count=count, from_date=from_date))
    else:
        while count > 0: # 4000 <= 4500? -> T
            current_count = min(count, CANDLE_COUNT)
            candles.extend(get_candles(p_count=current_count, from_date=from_date)) # fetch 4000 candles
            # decrease count by current count -> 4500 - 4000 = 500 
            count -= current_count
            from_date = parser.parse(candles[-1]["time"])
            if from_date >= to_date:
                break

    return candles

# %%
df = pd.DataFrame(collect_large_candle_data(pair='EUR_USD', granularity='M1', date_from='2016-08-01T00:00:00Z', date_to='2024-08-02T00:00:00Z'))
# Out:
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-01T00:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-04T00:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-09T04:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-12T06:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-17T08:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-22T06:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-25T06:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-08-30T06:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-02T07:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-07T09:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-12T09:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-15T08:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-20T09:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-23T08:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-09-28T08:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-03T07:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-06T07:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-11T06:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-14T03:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-19T04:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-24T05:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-10-27T06:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-01T06:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-04T06:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-09T04:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-13T23:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-16T19:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-21T15:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-24T13:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-11-29T10:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-02T07:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-07T03:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-12T01:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-14T23:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-19T19:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-22T16:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2016-12-28T18:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-03T16:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-06T12:31:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-11T08:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-16T05:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-19T01:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-23T21:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-26T17:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-01-31T13:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-03T09:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-08T05:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-13T02:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-15T23:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-20T20:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-23T17:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-02-28T15:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-03T12:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-08T10:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-13T06:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-16T04:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-21T02:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-24T01:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-28T23:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-03-31T20:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-04-05T20:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-04-10T18:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-04-13T17:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-04-18T21:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-04-23T22:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-04-26T19:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-01T21:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-04T22:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-09T19:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-12T19:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-17T19:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-22T17:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-25T15:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-05-30T17:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-02T16:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-07T16:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-12T14:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-15T14:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-20T14:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-23T16:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-06-28T16:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-03T15:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-06T16:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-11T16:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-14T15:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-19T14:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-24T11:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-07-27T08:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-01T05:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-04T01:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-08T22:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-11T19:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-16T16:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-21T13:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-24T11:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-08-29T08:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-01T04:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-06T02:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-10T22:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-13T18:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-18T15:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-21T12:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-26T08:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-09-29T05:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-04T01:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-08T23:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-11T20:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-16T18:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-19T16:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-24T14:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-10-27T11:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-01T09:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-06T08:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-09T05:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-14T04:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-17T01:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-21T23:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-24T21:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-11-29T18:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-04T15:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-07T12:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-12T10:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-15T08:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-20T07:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-26T06:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2017-12-29T08:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-04T06:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-09T05:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-12T01:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-16T21:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-19T16:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-24T12:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-01-29T08:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-01T03:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-05T22:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-08T18:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-13T13:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-16T09:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-21T06:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-26T02:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-02-28T22:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-05T17:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-08T14:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-13T10:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-16T08:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-21T05:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-26T02:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-03-28T23:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-03T03:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-06T01:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-10T21:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-13T19:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-18T18:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-23T17:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-04-26T15:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-01T14:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-04T12:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-09T10:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-14T08:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-17T04:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-22T01:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-24T22:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-05-29T20:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-01T16:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-06T13:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-11T11:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-14T08:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-19T05:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-22T01:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-26T22:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-06-29T17:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-04T14:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-09T12:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-12T08:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-17T05:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-20T01:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-24T21:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-07-27T17:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-01T15:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-06T13:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-09T12:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-14T08:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-17T04:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-22T01:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-26T21:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-08-29T18:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-03T15:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-06T13:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-11T11:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-14T10:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-19T08:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-24T06:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-09-27T04:31:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-02T01:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-04T23:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-09T20:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-12T16:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-17T14:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-22T11:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-25T09:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-10-30T06:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-02T03:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-07T01:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-09T20:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-14T16:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-19T13:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-22T11:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-27T10:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-11-30T07:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-05T03:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-09T23:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-12T19:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-17T17:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-20T14:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-26T13:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2018-12-31T10:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-04T06:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-09T03:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-14T00:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-16T21:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-21T20:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-24T18:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-01-29T16:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-01T14:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-06T14:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-11T14:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-14T14:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-19T16:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-22T15:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-02-27T15:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-04T15:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-07T15:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-12T14:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-15T16:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-20T18:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-25T17:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-03-28T15:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-02T16:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-05T19:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-10T23:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-16T03:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-19T10:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-24T20:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-04-30T02:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-03T07:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-08T07:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-13T07:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-16T09:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-21T12:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-24T16:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-05-30T02:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-04T03:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-07T04:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-12T07:31:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-17T10:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-20T12:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-25T11:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-06-28T12:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-03T11:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-08T20:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-12T01:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-17T03:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-22T03:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-25T08:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-07-30T12:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-02T11:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-07T08:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-12T08:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-15T08:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-20T09:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-23T13:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-08-28T12:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-02T13:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-05T16:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-10T19:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-15T21:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-18T22:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-23T23:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-09-27T00:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-02T01:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-07T03:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-10T06:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-15T06:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-18T08:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-23T13:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-28T19:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-10-31T23:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-11-06T04:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-11-11T08:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-11-14T11:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-11-19T18:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-11-25T02:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-11-28T09:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-12-03T17:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-12-09T03:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-12-12T11:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-12-17T10:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-12-20T14:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2019-12-27T03:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-02T06:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-07T08:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-10T10:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-15T09:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-20T09:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-23T08:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-28T07:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-01-31T05:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-05T03:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-10T02:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-12T23:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-17T21:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-20T19:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-25T15:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-02-28T11:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-04T07:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-09T01:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-11T20:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-16T15:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-19T11:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-24T06:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-27T02:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-03-31T21:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-03T17:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-08T13:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-13T14:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-16T11:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-21T07:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-24T04:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-04-29T00:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-01T20:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-06T17:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-11T13:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-14T11:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-19T07:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-22T04:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-27T02:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-05-31T23:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-03T19:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-08T15:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-11T12:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-16T08:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-19T04:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-24T00:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-06-26T20:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-01T17:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-06T14:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-09T11:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-14T08:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-17T05:31:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-22T01:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-26T22:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-07-29T18:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-03T14:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-06T11:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-11T07:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-14T04:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-19T01:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-21T20:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-26T17:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-08-31T14:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-03T11:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-08T08:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-11T05:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-16T02:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-20T22:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-23T18:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-09-28T15:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-01T12:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-06T09:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-09T06:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-14T03:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-18T23:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-21T19:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-26T16:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-10-29T12:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-03T10:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-06T05:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-11T01:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-13T20:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-18T16:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-23T12:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-11-26T09:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-01T06:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-04T02:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-08T21:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-11T17:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-16T14:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-21T10:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-24T06:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2020-12-30T04:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-05T00:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-07T19:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-12T15:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-15T11:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-20T08:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-25T04:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-01-28T00:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-01T19:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-04T15:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-09T11:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-12T07:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-17T03:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-22T00:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-02-24T19:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-01T15:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-04T11:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-09T07:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-12T03:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-16T22:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-19T18:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-24T14:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-03-29T11:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-01T07:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-06T06:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-09T03:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-13T23:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-16T20:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-21T16:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-26T13:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-04-29T10:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-04T08:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-07T05:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-12T02:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-16T23:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-19T19:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-24T16:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-05-27T13:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-01T11:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-04T08:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-09T07:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-14T04:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-17T01:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-21T22:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-24T18:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-06-29T15:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-02T12:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-07T10:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-12T06:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-15T03:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-20T00:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-22T21:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-27T18:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-07-30T15:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-04T13:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-09T10:31:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-12T08:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-17T06:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-20T02:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-25T00:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-08-29T21:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-01T19:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-06T17:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-09T16:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-14T13:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-17T10:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-22T08:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-27T05:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-09-30T02:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-05T00:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-07T20:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-12T17:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-15T14:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-20T11:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-25T09:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-10-28T06:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-02T02:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-04T23:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-09T20:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-12T16:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-17T12:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-22T10:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-25T06:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-11-30T03:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-03T00:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-07T19:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-10T16:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-15T13:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-20T09:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-23T06:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-28T08:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2021-12-31T06:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-05T04:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-10T00:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-12T21:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-17T18:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-20T15:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-25T12:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-01-28T09:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-02T06:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-07T02:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-09T23:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-14T18:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-17T14:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-22T09:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-02-25T04:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-01T23:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-04T18:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-09T13:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-14T07:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-17T03:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-21T22:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-24T17:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-03-29T12:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-01T08:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-06T03:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-10T22:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-13T17:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-18T13:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-21T08:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-26T04:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-04-28T23:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-03T18:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-06T15:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-11T10:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-16T08:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-19T04:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-23T23:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-26T18:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-05-31T14:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-03T09:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-08T05:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-13T00:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-15T19:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-20T15:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-23T10:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-06-28T07:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-01T02:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-05T22:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-08T17:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-13T13:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-18T08:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-21T04:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-25T23:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-07-28T18:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-02T13:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-05T09:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-10T04:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-14T23:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-17T18:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-22T14:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-25T09:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-08-30T07:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-02T02:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-06T21:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-09T16:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-14T11:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-19T07:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-22T02:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-26T21:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-09-29T16:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-04T11:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-07T06:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-12T01:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-14T20:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-19T16:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-24T11:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-10-27T06:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-01T02:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-03T21:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-08T17:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-11T12:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-16T07:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-21T02:47:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-23T21:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-11-28T16:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-01T11:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-06T06:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-09T02:08:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-13T21:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-16T16:12:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-21T11:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-27T06:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2022-12-30T01:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-04T04:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-08T23:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-11T18:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-16T13:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-19T09:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-24T04:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-26T23:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-01-31T18:27:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-03T13:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-08T08:55:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-13T04:03:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-15T23:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-20T18:18:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-23T13:42:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-02-28T08:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-03T03:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-07T23:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-10T18:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-15T12:00:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-20T07:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-23T02:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-27T22:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-03-30T17:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-04T12:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-07T08:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-12T05:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-17T00:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-19T19:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-24T15:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-04-27T10:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-02T05:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-05T00:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-09T19:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-12T15:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-17T10:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-22T06:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-25T01:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-05-29T21:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-01T16:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-06T12:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-09T07:45:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-14T02:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-18T22:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-21T17:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-26T12:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-06-29T08:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-04T04:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-06T23:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-11T19:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-14T14:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-19T09:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-24T05:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-27T00:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-07-31T19:40:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-03T14:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-08T10:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-11T05:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-16T00:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-18T19:56:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-23T15:21:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-28T10:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-08-31T06:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-05T02:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-07T22:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-12T17:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-15T13:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-20T09:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-25T04:48:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-09-28T00:09:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-02T19:26:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-05T14:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-10T10:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-13T05:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-18T01:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-20T20:23:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-25T15:46:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-10-30T11:05:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-02T06:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-07T02:39:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-09T21:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-14T17:06:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-17T12:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-22T07:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-27T03:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-11-29T22:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-04T17:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-07T13:02:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-12T08:20:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-15T03:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-19T22:25:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-22T17:28:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2023-12-28T13:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-03T08:36:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-08T03:44:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-10T22:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-15T17:57:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-18T13:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-23T08:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-26T03:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-01-30T22:41:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-02T17:38:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-07T12:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-12T08:13:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-15T03:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-19T22:53:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-22T17:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-02-27T13:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-01T08:14:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-06T03:17:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-10T21:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-13T16:34:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-18T11:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-21T07:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-26T02:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-03-28T22:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-02T17:49:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-05T13:30:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-10T08:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-15T04:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-17T23:15:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-22T18:24:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-25T13:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-04-30T09:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-03T04:10:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-08T00:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-10T19:11:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-15T14:59:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-20T10:35:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-23T09:07:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-28T05:33:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-05-31T00:51:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-04T19:52:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-07T15:16:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-12T10:50:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-17T06:22:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-20T02:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-24T22:01:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-06-27T17:37:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-02T12:54:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-05T09:19:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-10T05:04:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-15T00:32:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-17T19:43:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-22T14:58:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-25T10:29:00Z', 'count': 4000}
# {'granularity': 'M1', 'price': 'MBA', 'from': '2024-07-30T06:04:00Z', 'count': 4000}

# %%
df.tail(10)
# Out:
#          complete  volume                            time  \
# 2875990      True      40  2024-08-02T01:06:00.000000000Z
# 2875991      True      39  2024-08-02T01:07:00.000000000Z
# 2875992      True      58  2024-08-02T01:08:00.000000000Z
# 2875993      True      66  2024-08-02T01:09:00.000000000Z
# 2875994      True      45  2024-08-02T01:10:00.000000000Z
# 2875995      True      28  2024-08-02T01:11:00.000000000Z
# 2875996      True      34  2024-08-02T01:12:00.000000000Z
# 2875997      True      64  2024-08-02T01:13:00.000000000Z
# 2875998      True      63  2024-08-02T01:14:00.000000000Z
# 2875999      True      72  2024-08-02T01:15:00.000000000Z
#
#                                                        bid  \
# 2875990  {'o': '1.07894', 'h': '1.07897', 'l': '1.07893...
# 2875991  {'o': '1.07896', 'h': '1.07896', 'l': '1.07892...
# 2875992  {'o': '1.07892', 'h': '1.07902', 'l': '1.07892...
# 2875993  {'o': '1.07900', 'h': '1.07912', 'l': '1.07899...
# 2875994  {'o': '1.07912', 'h': '1.07914', 'l': '1.07908...
# 2875995  {'o': '1.07912', 'h': '1.07912', 'l': '1.07903...
# 2875996  {'o': '1.07905', 'h': '1.07905', 'l': '1.07902...
# 2875997  {'o': '1.07899', 'h': '1.07904', 'l': '1.07895...
# 2875998  {'o': '1.07902', 'h': '1.07910', 'l': '1.07900...
# 2875999  {'o': '1.07904', 'h': '1.07905', 'l': '1.07893...
#
#                                                        mid  \
# 2875990  {'o': '1.07902', 'h': '1.07904', 'l': '1.07900...
# 2875991  {'o': '1.07904', 'h': '1.07904', 'l': '1.07900...
# 2875992  {'o': '1.07900', 'h': '1.07910', 'l': '1.07900...
# 2875993  {'o': '1.07908', 'h': '1.07919', 'l': '1.07907...
# 2875994  {'o': '1.07919', 'h': '1.07922', 'l': '1.07916...
# 2875995  {'o': '1.07919', 'h': '1.07919', 'l': '1.07911...
# 2875996  {'o': '1.07912', 'h': '1.07913', 'l': '1.07910...
# 2875997  {'o': '1.07907', 'h': '1.07912', 'l': '1.07902...
# 2875998  {'o': '1.07910', 'h': '1.07918', 'l': '1.07908...
# 2875999  {'o': '1.07911', 'h': '1.07912', 'l': '1.07900...
#
#                                                        ask
# 2875990  {'o': '1.07910', 'h': '1.07912', 'l': '1.07908...
# 2875991  {'o': '1.07912', 'h': '1.07912', 'l': '1.07907...
# 2875992  {'o': '1.07908', 'h': '1.07917', 'l': '1.07907...
# 2875993  {'o': '1.07916', 'h': '1.07927', 'l': '1.07915...
# 2875994  {'o': '1.07926', 'h': '1.07929', 'l': '1.07924...
# 2875995  {'o': '1.07926', 'h': '1.07926', 'l': '1.07919...
# 2875996  {'o': '1.07920', 'h': '1.07921', 'l': '1.07917...
# 2875997  {'o': '1.07915', 'h': '1.07919', 'l': '1.07910...
# 2875998  {'o': '1.07918', 'h': '1.07926', 'l': '1.07916...
# 2875999  {'o': '1.07918', 'h': '1.07919', 'l': '1.07908...

# %%
c_list[-1]["time"]
# Out:
# '2023-09-15T16:00:00.000000000Z'

# %%
c_list = []
c1 = fetch_candles(
    pair_name='EUR_USD',
    start="2020-01-01",
    granularity='M5',
    count=1,
    price='MBA'
)
c2 = fetch_candles(
    pair_name='EUR_USD',
    start="2020-01-01",
    granularity='H1',
    count=1,
    price='MBA'
)

# %%
d1 = parser.parse("2020-01-01")

d2 = parser.parse("2020-01-02")

# %%
# Out:
# True
